# %%
import re

# %%
pat="href=\'.*\'"

# %%
pat=re.compile(r'(href=)(\'http://foodbakery.chimpgroup.com/w)(\S*)(\?ver=\S*\')')

# %%
r="""
Enter Html page here
"""

# %%
type(r)
# Out:
# str

# %%
mo = pat.findall(r)

# %%
len(mo)
# Out:
# 22

# %%
mo
# Out:
# [('href=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/assets/common/icomoon/css/iconmoon.css',
#   "?ver=5.3.2'"),
#  ('href=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/assets/frontend/css/bootstrap.css',
#   "?ver=5.3.2'"),
#  ('href=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/assets/frontend/css/bootstrap-theme.css',
#   "?ver=5.3.2'"),
#  ('href=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/assets/frontend/css/chosen.css',
#   "?ver=5.3.2'"),
#  ('href=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/assets/frontend/css/swiper.css',
#   "?ver=5.3.2'"),
#  ('href=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/assets/frontend/css/animate.css',
#   "?ver=5.3.2'"),
#  ('href=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/style.css',
#   "?ver=5.3.2'"),
# ...

# %%
mo2 = pat.sub('href=\"{% static \'w\\3\' %}\"',r)

# %%
import pprint
str(mo2)
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en-US">\n    <head>\n                <meta charset="UTF-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <link rel="profile" href="http://gmpg.org/xfn/11">\n        <link rel="pingback" href="http://foodbakery.chimpgroup.com/xmlrpc.php">\n        <title>User Dashboard &#8211; Foodbakery</title>\n<link rel=\'dns-prefetch\' href=\'//maps.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Foodbakery &raquo; Feed" href="http://foodbakery.chimpgroup.com/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Foodbakery &raquo; Comments Feed" href="http://foodbakery.chimpgroup.com/comments/feed/" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/cor
# ...

# %%
fi=open('index.html','w')
fi.write(mo2)
fi.close()

# %%
# pat2 =re.compile(r'(src=)(\'\S*\')')
pat2 =re.compile(r'(src=)(\'http://foodbakery.chimpgroup.com/w)(\S*)(\?ver=\S*\')')

# %%
pat2.findall(mo2)
# Out:
# [('src=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-includes/js/jquery/jquery.js',
#   "?ver=1.12.4-wp'"),
#  ('src=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-includes/js/jquery/jquery-migrate.min.js',
#   "?ver=1.4.1'"),
#  ('src=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/themes/foodbakery/assets/common/js/chosen.select.js',
#   "?ver=1.8'"),
#  ('src=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/plugins/wp-foodbakery/assets/frontend/scripts/jquery_latlon_picker.js',
#   "?ver=5.3.2'"),
#  ('src=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/plugins/wp-foodbakery/assets/common/js/icons-loader.js',
#   "?ver=5.3.2'"),
#  ('src=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/plugins/wp-foodbakery/assets/frontend/scripts/functions.js',
#   "?ver=5.3.2'"),
#  ('src=',
#   "'http://foodbakery.chimpgroup.com/w",
#   'p-content/plugins/wp-foodbakery/assets/frontend/scripts/theia-sticky-sidebar.js',
# ...

# %%
len(pat2.findall(mo2))
# Out:
# 46

# %%
mo3 = pat2.sub('src=\"{% static \'w\\3\' %}\"',mo2)

# %%
mo3
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en-US">\n    <head>\n                <meta charset="UTF-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <link rel="profile" href="http://gmpg.org/xfn/11">\n        <link rel="pingback" href="http://foodbakery.chimpgroup.com/xmlrpc.php">\n        <title>User Dashboard &#8211; Foodbakery</title>\n<link rel=\'dns-prefetch\' href=\'//maps.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Foodbakery &raquo; Feed" href="http://foodbakery.chimpgroup.com/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Foodbakery &raquo; Comments Feed" href="http://foodbakery.chimpgroup.com/comments/feed/" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/cor
# ...

# %%
fi=open('index.html','w')
fi.write(mo3)
fi.close()

# %%
pat3 =re.compile(r'(src=)(\"http://foodbakery.chimpgroup.com/w)(\S*)\"')

# %%
jpg = pat3.findall(mo3)

# %%
jpg
# Out:
# [('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/main-logo.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/main-logo.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-05-1.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-19-1.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-10-1.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-18-1.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-28-1.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-21-1.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-25-1.png'),
#  ('src=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/uploads/food-icon-30-1.png'),
# ...

# %%
mo4 = pat3.sub('src=\"{% static \'w\\3\' %}\"',mo3)

# %%
fi=open('index.html','w')
fi.write(mo4)
fi.close()

# %%
pat4 =re.compile(r'(href=)(\"http://foodbakery.chimpgroup.com/w)(\S*)\"')

# %%
href2 = pat4.findall(mo4)

# %%
href2
# Out:
# [('href=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-content/themes/foodbakery/assets/common/icomoon/css/iconmoon9537.css?ver=5.3.2'),
#  ('href=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-includes/wlwmanifest.xml'),
#  ('href=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-json/oembed/1.0/embed?url=http%3A%2F%2Ffoodbakery.chimpgroup.com%2Fuser-dashboard%2F'),
#  ('href=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-json/oembed/1.0/embed?url=http%3A%2F%2Ffoodbakery.chimpgroup.com%2Fuser-dashboard%2F&#038;format=xml'),
#  ('href=',
#   '"http://foodbakery.chimpgroup.com/w',
#   'p-login.php?action=logout&#038;redirect_to=http%3A%2F%2Ffoodbakery.chimpgroup.com%2Fuser-dashboard%2F%3Fdashboard%3Dreceived_orders%26page_id_all%3D1&#038;_wpnonce=8bc8a28bd6'),
#  ('href=',
#   '"http://foodbakery.chimpgroup.com/w',
# ...

# %%
mo5 = pat4.sub('href=\"{% static \'w\\3\' %}\"',mo4)

# %%
fi=open('index.html','w')
fi.write(mo5)
fi.close()
